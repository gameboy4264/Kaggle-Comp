# %%
import pandas as pd

# %%
pd
# Out:
# <module 'pandas' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\pandas\\__init__.py'>

# %%
import numpy as np

# %%
np
# Out:
# <module 'numpy' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\numpy\\__init__.py'>

# %%
ls
# Out:
#  驱动器 C 中的卷没有标签。
#  卷的序列号是 7663-EDFD
#
#  C:\Users\Administrator\Desktop 的目录
#
# 2020/03/31  19:29    <DIR>          .
# 2020/03/31  19:29    <DIR>          ..
# 2020/03/31  18:57    <DIR>          .ipynb_checkpoints
# 2020/03/31  19:29         2,530,295 0330.csv
# 2020/03/31  15:23         1,427,372 999999.xls
# 2020/03/31  14:49               717 gameboy4264.lnk
# 2020/03/27  15:11             1,738 powershell.exe.lnk
# 2020/03/16  21:13             2,054 Umeet网络会议.lnk
# 2020/03/31  19:27             1,618 Untitled.ipynb
# 2020/03/30  10:09               954 WESTWORLD (Season 01) DUB 720.lnk
# 2020/03/25  15:47    <DIR>          财报
# 2020/03/30  17:04    <DIR>          股票
# 2019/12/14  11:23               878 翰林湾资料.lnk
# 2020/03/30  17:15         3,240,194 沪深Ａ股20200330.xls
# 2020/03/30  16:24    <DIR>          基坑支护方案广腾20200330
# 2020/03/19  15:45    <DIR>          集团管控重点
# 2020/03/30  16:22    <DIR>          三方检查20200327
# 2020/03/30  15:40        11,201,139 项目周例会-翰林湾2020.3.30.pptx
# ...

# %%
stock = pd.read_csv('0330.csv')

# %%
stock.head()
# Out:
#        代码    名称    涨幅%    现价    涨跌    买价    卖价         总量      现量 涨速%  ...  \
# 0  600313  农发种业  10.14  3.91  0.36  3.91  --    2191583.0  4530.0   0  ...
# 1  600361  华联综超   10.1  4.36   0.4  4.36  --     472217.0  2822.0   0  ...
# 2  000678  襄阳轴承  10.08  6.99  0.64  6.99  --     157575.0  2633.0   0  ...
# 3  002571  德力股份  10.07  5.90  0.54   5.9  --     495739.0  1297.0   0  ...
# 4  600366  宁波韵升  10.05  6.02  0.55  6.02  --     408606.0   800.0   0  ...
#
#        净益率%   毛利率%  营业利润率%  净利润率%  研发费用(亿)   员工人数      交易代码   自选日   自选价 自选收益%
# 0     1.26㈣   5.57    1.02   0.35     0.34   1098  600313.0  --    --    --
# 1     2.28㈢  21.94     0.7   0.67     --    17210  600361.0  --    --    --
# 2    -2.08㈢   10.6   -2.27  -2.52     0.25   4464     678.0  --    --    --
# 3     3.02㈢   21.9     7.8   7.28     0.02   2203    2571.0  --    --    --
# 4     1.10㈢  17.96    4.38   3.48     1.03   3418  600366.0  --    --    --
#
# [5 rows x 113 columns]

# %%
stock
# Out:
#             代码     名称    涨幅%    现价    涨跌    买价    卖价         总量      现量   涨速%  \
# 0       600313   农发种业  10.14  3.91  0.36  3.91  --    2191583.0  4530.0     0
# 1       600361   华联综超   10.1  4.36   0.4  4.36  --     472217.0  2822.0     0
# 2       000678   襄阳轴承  10.08  6.99  0.64  6.99  --     157575.0  2633.0     0
# 3       002571   德力股份  10.07  5.90  0.54   5.9  --     495739.0  1297.0     0
# 4       600366   宁波韵升  10.05  6.02  0.55  6.02  --     408606.0   800.0     0
# ...        ...    ...    ...   ...   ...   ...   ...        ...     ...   ...
# 3816    002979   雷赛智能   --    0.00  --    --    --          0.0     0.0  --
# 3817    002978   安宁股份   --    0.00  --    --    --          0.0     0.0  --
# 3818    002604  *ST龙力   --    0.00  --    --    --          0.0     0.0  --
# 3819    002260  *ST德奥   --    0.00  --    --    --          0.0     0.0  --
# 3820  数据来源:通达信    NaN    NaN   NaN   NaN   NaN   NaN        NaN     NaN   NaN
#
# ...

# %%
stock.count()
# Out:
# 代码       3821
# 名称       3820
# 涨幅%      3820
# 现价       3820
# 涨跌       3820
#          ...
# 员工人数     3820
# 交易代码     3820
# 自选日      3820
# 自选价      3820
# 自选收益%    3820
# Length: 113, dtype: int64

# %%
stock.总量
# Out:
# 0       2191583.0
# 1        472217.0
# 2        157575.0
# 3        495739.0
# 4        408606.0
#           ...
# 3816          0.0
# 3817          0.0
# 3818          0.0
# 3819          0.0
# 3820          NaN
# Name: 总量, Length: 3821, dtype: float64

# %%
stock.count
# Out:
# <bound method DataFrame.count of             代码     名称    涨幅%    现价    涨跌    买价    卖价         总量      现量   涨速%  \
# 0       600313   农发种业  10.14  3.91  0.36  3.91  --    2191583.0  4530.0     0
# 1       600361   华联综超   10.1  4.36   0.4  4.36  --     472217.0  2822.0     0
# 2       000678   襄阳轴承  10.08  6.99  0.64  6.99  --     157575.0  2633.0     0
# 3       002571   德力股份  10.07  5.90  0.54   5.9  --     495739.0  1297.0     0
# 4       600366   宁波韵升  10.05  6.02  0.55  6.02  --     408606.0   800.0     0
# ...        ...    ...    ...   ...   ...   ...   ...        ...     ...   ...
# 3816    002979   雷赛智能   --    0.00  --    --    --          0.0     0.0  --
# 3817    002978   安宁股份   --    0.00  --    --    --          0.0     0.0  --
# 3818    002604  *ST龙力   --    0.00  --    --    --          0.0     0.0  --
# 3819    002260  *ST德奥   --    0.00  --    --    --          0.0     0.0  --
# 3820  数据来源:通达信    NaN    NaN   NaN   NaN   NaN   NaN        NaN     NaN   NaN
#
# ...

# %%
stock.shape
# Out:
# (3821, 113)

# %%
stock.values
# Out:
# array([['600313', '农发种业', '10.14', ..., '--  ', '--  ', '--  '],
#        ['600361', '华联综超', '10.1', ..., '--  ', '--  ', '--  '],
#        ['000678', '襄阳轴承', '10.08', ..., '--  ', '--  ', '--  '],
#        ...,
#        ['002604', '*ST龙力', '--  ', ..., '--  ', '--  ', '--  '],
#        ['002260', '*ST德奥', '--  ', ..., '--  ', '--  ', '--  '],
#        ['数据来源:通达信', nan, nan, ..., nan, nan, nan]], dtype=object)

# %%
stock
# Out:
#             代码     名称    涨幅%    现价    涨跌    买价    卖价         总量      现量   涨速%  \
# 0       600313   农发种业  10.14  3.91  0.36  3.91  --    2191583.0  4530.0     0
# 1       600361   华联综超   10.1  4.36   0.4  4.36  --     472217.0  2822.0     0
# 2       000678   襄阳轴承  10.08  6.99  0.64  6.99  --     157575.0  2633.0     0
# 3       002571   德力股份  10.07  5.90  0.54   5.9  --     495739.0  1297.0     0
# 4       600366   宁波韵升  10.05  6.02  0.55  6.02  --     408606.0   800.0     0
# ...        ...    ...    ...   ...   ...   ...   ...        ...     ...   ...
# 3816    002979   雷赛智能   --    0.00  --    --    --          0.0     0.0  --
# 3817    002978   安宁股份   --    0.00  --    --    --          0.0     0.0  --
# 3818    002604  *ST龙力   --    0.00  --    --    --          0.0     0.0  --
# 3819    002260  *ST德奥   --    0.00  --    --    --          0.0     0.0  --
# 3820  数据来源:通达信    NaN    NaN   NaN   NaN   NaN   NaN        NaN     NaN   NaN
#
# ...

# %%
stock.3820
# Out:
#   File "<ipython-input-15-7c8135925e55>", line 1
#     stock.3820
#              ^
# SyntaxError: invalid syntax

# %%
stock.columns
# Out:
# Index(['代码', '名称', '涨幅%', '现价', '涨跌', '买价', '卖价', '总量', '现量', '涨速%',
#        ...
#        '净益率%', '毛利率%', '营业利润率%', '净利润率%', '研发费用(亿)', '员工人数', '交易代码', '自选日',
#        '自选价', '自选收益%'],
#       dtype='object', length=113)

# %%
stock.index
# Out:
# RangeIndex(start=0, stop=3821, step=1)

# %%
stock.代码
# Out:
# 0         600313
# 1         600361
# 2         000678
# 3         002571
# 4         600366
#           ...
# 3816      002979
# 3817      002978
# 3818      002604
# 3819      002260
# 3820    数据来源:通达信
# Name: 代码, Length: 3821, dtype: object

# %%
new_stock = stock.drop('3820')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-9492b6f6893b> in <module>
# ----> 1 new_stock = stock.drop('3820')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ...

# %%
new_stock = stock.drop('3820', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-a369575396ca> in <module>
# ----> 1 new_stock = stock.drop('3820', axis=1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ...

# %%
new_stock = stock.drop(['3820'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-aee9b12d8447> in <module>
# ----> 1 new_stock = stock.drop(['3820'], axis=1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ...

# %%
stock
# Out:
#             代码     名称    涨幅%    现价    涨跌    买价    卖价         总量      现量   涨速%  \
# 0       600313   农发种业  10.14  3.91  0.36  3.91  --    2191583.0  4530.0     0
# 1       600361   华联综超   10.1  4.36   0.4  4.36  --     472217.0  2822.0     0
# 2       000678   襄阳轴承  10.08  6.99  0.64  6.99  --     157575.0  2633.0     0
# 3       002571   德力股份  10.07  5.90  0.54   5.9  --     495739.0  1297.0     0
# 4       600366   宁波韵升  10.05  6.02  0.55  6.02  --     408606.0   800.0     0
# ...        ...    ...    ...   ...   ...   ...   ...        ...     ...   ...
# 3816    002979   雷赛智能   --    0.00  --    --    --          0.0     0.0  --
# 3817    002978   安宁股份   --    0.00  --    --    --          0.0     0.0  --
# 3818    002604  *ST龙力   --    0.00  --    --    --          0.0     0.0  --
# 3819    002260  *ST德奥   --    0.00  --    --    --          0.0     0.0  --
# 3820  数据来源:通达信    NaN    NaN   NaN   NaN   NaN   NaN        NaN     NaN   NaN
#
# ...

# %%
stock('3820')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-604fadc240de> in <module>
# ----> 1 stock('3820')
#
# TypeError: 'DataFrame' object is not callable

# %%
stock['代码']
# Out:
# 0         600313
# 1         600361
# 2         000678
# 3         002571
# 4         600366
#           ...
# 3816      002979
# 3817      002978
# 3818      002604
# 3819      002260
# 3820    数据来源:通达信
# Name: 代码, Length: 3821, dtype: object

# %%
stock['3819']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '3819'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-32353c864fae> in <module>
# ----> 1 stock['3819']
#
# ...

# %%
stock.loc[3819]
# Out:
# 代码       002260
# 名称        *ST德奥
# 涨幅%        --
# 现价            0
# 涨跌         --
#           ...
# 员工人数       1375
# 交易代码       2260
# 自选日        --
# 自选价        --
# 自选收益%      --
# Name: 3819, Length: 113, dtype: object

# %%
stock.loc[3820]
# Out:
# 代码       数据来源:通达信
# 名称            NaN
# 涨幅%           NaN
# 现价            NaN
# 涨跌            NaN
#            ...
# 员工人数          NaN
# 交易代码          NaN
# 自选日           NaN
# 自选价           NaN
# 自选收益%         NaN
# Name: 3820, Length: 113, dtype: object

# %%
stock[3820]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 3820
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-010210febc0b> in <module>
# ----> 1 stock[3820]
#
# ...

# %%
stock.loc[3820]
# Out:
# 代码       数据来源:通达信
# 名称            NaN
# 涨幅%           NaN
# 现价            NaN
# 涨跌            NaN
#            ...
# 员工人数          NaN
# 交易代码          NaN
# 自选日           NaN
# 自选价           NaN
# 自选收益%         NaN
# Name: 3820, Length: 113, dtype: object

# %%
del stock.loc[3820]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-9f6b44b21a4e> in <module>
# ----> 1 del stock.loc[3820]
#
# AttributeError: __delitem__

# %%
stock
# Out:
#             代码     名称    涨幅%    现价    涨跌    买价    卖价         总量      现量   涨速%  \
# 0       600313   农发种业  10.14  3.91  0.36  3.91  --    2191583.0  4530.0     0
# 1       600361   华联综超   10.1  4.36   0.4  4.36  --     472217.0  2822.0     0
# 2       000678   襄阳轴承  10.08  6.99  0.64  6.99  --     157575.0  2633.0     0
# 3       002571   德力股份  10.07  5.90  0.54   5.9  --     495739.0  1297.0     0
# 4       600366   宁波韵升  10.05  6.02  0.55  6.02  --     408606.0   800.0     0
# ...        ...    ...    ...   ...   ...   ...   ...        ...     ...   ...
# 3816    002979   雷赛智能   --    0.00  --    --    --          0.0     0.0  --
# 3817    002978   安宁股份   --    0.00  --    --    --          0.0     0.0  --
# 3818    002604  *ST龙力   --    0.00  --    --    --          0.0     0.0  --
# 3819    002260  *ST德奥   --    0.00  --    --    --          0.0     0.0  --
# 3820  数据来源:通达信    NaN    NaN   NaN   NaN   NaN   NaN        NaN     NaN   NaN
#
# ...

# %%
obj = pd.Series(np.arange(5.), index=['a', 'b', 'c', 'd', 'e'])

# %%
obj
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# e    4.0
# dtype: float64

# %%
new_obj = obj.drop('c')

# %%
new_obj
# Out:
# a    0.0
# b    1.0
# d    3.0
# e    4.0
# dtype: float64

# %%
obj
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# e    4.0
# dtype: float64

# %%
obj('c')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-edabdf1bf22c> in <module>
# ----> 1 obj('c')
#
# TypeError: 'Series' object is not callable

# %%
stock.describe()
# Out:
#                 现价            总量            现量  短期形态  中期形态  长期形态  \
# count  3820.000000  3.820000e+03   3820.000000   0.0   0.0   0.0
# mean     16.242822  1.560126e+05   1924.212304   NaN   NaN   NaN
# std      30.817015  3.039205e+05   4015.200568   NaN   NaN   NaN
# min       0.000000  0.000000e+00      0.000000   NaN   NaN   NaN
# 25%       5.030000  3.023775e+04    293.750000   NaN   NaN   NaN
# 50%       8.820000  7.285300e+04    788.000000   NaN   NaN   NaN
# 75%      16.870000  1.699680e+05   2012.000000   NaN   NaN   NaN
# max    1072.000000  9.683080e+06  76031.000000   NaN   NaN   NaN
#
#                 总金额           均价            内盘            外盘  ...  \
# count  3.820000e+03  3820.000000  3.820000e+03  3.820000e+03  ...
# mean   1.656975e+08    16.202709  8.005955e+04  7.595307e+04  ...
# std    3.278064e+08    30.659296  1.451905e+05  1.603928e+05  ...
# min    0.000000e+00     0.000000  0.000000e+00  0.000000e+00  ...
# ...

# %%
cleaned = stock.dropna()

# %%
cleaned
# Out:
# Empty DataFrame
# Columns: [代码, 名称, 涨幅%, 现价, 涨跌, 买价, 卖价, 总量, 现量, 涨速%, 换手%, 今开, 短期形态, 中期形态, 长期形态, 市盈(TTM), 最高, 最低, 昨收, 市盈(动), 总金额, 量比, 细分行业, 地区, 振幅%, 均价, 内盘, 外盘, 内外比, 买量, 卖量, 未匹配量, 开盘金额, 开盘换手Z, 封成比, 封单额, 流通股(亿), 流通市值, AB股总市值, 强弱度%, 活跃度, 笔均量, 笔换手, 连涨天, 3日涨幅%, 20日涨幅%, 60日涨幅%, 年初至今%, 换手Z, 流通市值Z, 市盈(静), 贝塔系数, 开盘%, 最高%, 最低%, 均涨幅%, 实体涨幅%, 回头波%, 攻击波%, 现均差%, 财务更新, 上市日期, 总股本(亿), B/A股(亿), H股(亿), 总资产(亿), 净资产(亿), 少数股权(亿), 资产负债率%, 流动资产(亿), 固定资产(亿), 无形资产(亿), 流动负债(亿), 存货(亿), 应收帐款(亿), 资本公积金(亿), 营业收入(亿), 营业成本(亿), 营业利润(亿), 投资收益(亿), 利润总额(亿), 税后利润(亿), 净利润(亿), 扣非净利润(亿), 未分利润(亿), 经营现金流(亿), 总现金流(亿), 股东人数, 人均持股, 人均市值, 利润同比%, 收入同比%, 市净率, 市现率, 市销率, 股息率%, 每股收益, 每股净资, 调整后净资, 每股公积, ...]
# Index: []
#
# [0 rows x 113 columns]

# %%
stock
# Out:
#             代码     名称    涨幅%    现价    涨跌    买价    卖价         总量      现量   涨速%  \
# 0       600313   农发种业  10.14  3.91  0.36  3.91  --    2191583.0  4530.0     0
# 1       600361   华联综超   10.1  4.36   0.4  4.36  --     472217.0  2822.0     0
# 2       000678   襄阳轴承  10.08  6.99  0.64  6.99  --     157575.0  2633.0     0
# 3       002571   德力股份  10.07  5.90  0.54   5.9  --     495739.0  1297.0     0
# 4       600366   宁波韵升  10.05  6.02  0.55  6.02  --     408606.0   800.0     0
# ...        ...    ...    ...   ...   ...   ...   ...        ...     ...   ...
# 3816    002979   雷赛智能   --    0.00  --    --    --          0.0     0.0  --
# 3817    002978   安宁股份   --    0.00  --    --    --          0.0     0.0  --
# 3818    002604  *ST龙力   --    0.00  --    --    --          0.0     0.0  --
# 3819    002260  *ST德奥   --    0.00  --    --    --          0.0     0.0  --
# 3820  数据来源:通达信    NaN    NaN   NaN   NaN   NaN   NaN        NaN     NaN   NaN
#
# ...

# %%
stock2 = stock.drop(3820, axis=0)

# %%
stock2
# Out:
#           代码     名称    涨幅%    现价    涨跌    买价    卖价         总量      现量   涨速%  \
# 0     600313   农发种业  10.14  3.91  0.36  3.91  --    2191583.0  4530.0     0
# 1     600361   华联综超   10.1  4.36   0.4  4.36  --     472217.0  2822.0     0
# 2     000678   襄阳轴承  10.08  6.99  0.64  6.99  --     157575.0  2633.0     0
# 3     002571   德力股份  10.07  5.90  0.54   5.9  --     495739.0  1297.0     0
# 4     600366   宁波韵升  10.05  6.02  0.55  6.02  --     408606.0   800.0     0
# ...      ...    ...    ...   ...   ...   ...   ...        ...     ...   ...
# 3815  002980    华盛昌   --    0.00  --    --    --          0.0     0.0  --
# 3816  002979   雷赛智能   --    0.00  --    --    --          0.0     0.0  --
# 3817  002978   安宁股份   --    0.00  --    --    --          0.0     0.0  --
# 3818  002604  *ST龙力   --    0.00  --    --    --          0.0     0.0  --
# 3819  002260  *ST德奥   --    0.00  --    --    --          0.0     0.0  --
#
# ...

# %%
stock2.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-6e74fb749a0f> in <module>
# ----> 1 stock2.shape()
#
# TypeError: 'tuple' object is not callable

# %%
stock2.shape
# Out:
# (3820, 113)

# %%
stock2.columns
# Out:
# Index(['代码', '名称', '涨幅%', '现价', '涨跌', '买价', '卖价', '总量', '现量', '涨速%',
#        ...
#        '净益率%', '毛利率%', '营业利润率%', '净利润率%', '研发费用(亿)', '员工人数', '交易代码', '自选日',
#        '自选价', '自选收益%'],
#       dtype='object', length=113)
